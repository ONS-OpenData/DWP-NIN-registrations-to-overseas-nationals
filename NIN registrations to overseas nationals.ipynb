# %% [markdown]
# Table 1: NINo registrations to adult overseas nationals entering the UK by quarter of registration and world region

# %%
from databaker.framework import *
import pandas as pd

# %%
import pandas as pd
from pyexcel_ods import get_data
data = get_data("nino-registrations-adult-overseas-nationals-march-2018-tables.ods")
data = data['1']
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                    0       1   \
# 0                                                None    None
# 1   Table 1: NINo registrations to adult overseas ...    None
# 2   Note : Caution should be taken in interpreting...    None
# 3                                                None    None
# 4
# 5                                                       TOTAL
# 6                                                None    None
# 7                                    Jan-02 to Mar-02   69701
# 8                                    Apr-02 to Jun-02   56619
# 9                                    Jul-02 to Sep-02   94436
# 10                                   Oct-02 to Dec-02   90535
# 11                                   Jan-03 to Mar-03  104576
# 12                                   Apr-03 to Jun-03   75571
# 13                                   Jul-03 to Sep-03   94707
# 14                                   Oct-03 to Dec-03   87295
# ...

# %%
df.to_excel('nin.xls', index = False)

# %%
from pathlib import Path

# sourceFolder = Path('in')
# sourceFolder.mkdir(exist_ok=True)

# %run lib/scrape_ons.ipynb

# metadata = scrape('https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/710047/nino-registrations-adult-overseas-nationals-march-2018-tables.ods')
# metadata

# %% [markdown]
# https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/710047/nino-registrations-adult-overseas-nationals-march-2018-tables.ods

# %%
# inputFile = sourceFolder / 'data.xls'
# response = session.get(metadata['fileURL'])
# with open(inputFile, 'wb') as f:
#   f.write(response.content)
tab = loadxlstabs('nin.xls')[0]
# Out:
# Loading nin.xls which has size 17920 bytes
# Table names: ['Sheet1']

# %%
tab
# Out:
# {<N41 3536.0>, <N67 3805.0>, <N70 3441.0>, <O72 2623.0>, <B2 ''>, <G11 3732.0>, <K33 5380.0>, <I23 4333.0>, <C35 26385.0>, <C19 17221.0>, <D22 55587.0>, <B5 ''>, <G12 3512.0>, <G25 3908.0>, <E26 997.0>, <C32 29458.0>, <H50 2385.0>, <C41 25935.0>, <N1 13.0>, <C62 50591.0>, <H32 3337.0>, <I40 3763.0>, <H41 3859.0>, <J41 53768.0>, <B12 90535.0>, <M45 2209.0>, <M25 1188.0>, <A32 'Oct-07 to Dec-07'>, <D27 69501.0>, <A45 'Jan-11 to Mar-11'>, <K50 2400.0>, <N71 3685.0>, <I64 5386.0>, <K17 6386.0>, <E23 1674.0>, <D73 20630.0>, <G74 ''>, <J76 ''>, <L19 13318.0>, <A5 ''>, <K61 3467.0>, <O78 ''>, <A12 'Oct-02 to Dec-02'>, <G7 'Other Europe'>, <A37 'Jan-09 to Mar-09'>, <H62 3362.0>, <M5 ''>, <H66 3775.0>, <P10 4363.0>, <Q33 189.0>, <M2 ''>, <B39 154544.0>, <E6 'Asia'>, <F46 349.0>, <G59 4067.0>, <K48 3423.0>, <A76 'Source: Stat-Xplore, Department for Work and Pensions'>, <C46 25787.0>, <F76 ''>, <H4 ''>, <P44 5089.0>, <C15 19698.0>, <B42 149287.0>, <J27 18960.0>, <A34 'Apr-08 to Jun-08'>, <L47 8
# ...

# %%
savepreviewhtml(tab)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Sheet1</caption>
# ...

# %%
# type(tab[0])

# %%
observations = tab.excel_ref('B8').expand(DOWN).expand(RIGHT).is_not_blank()
savepreviewhtml(observations)
# Out:
# <div id="injblock1002">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc1" style="background-color:LightGreen">item 0</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Sheet1</caption>
# ...

# %%
Area = tab.excel_ref('B7').expand(RIGHT).is_not_blank()
savepreviewhtml(Area)
# Out:
# <div id="injblock1003">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc1" style="background-color:LightGreen">item 0</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Sheet1</caption>
# ...

# %%
Period = tab.excel_ref('A8').expand(DOWN).is_not_blank()
savepreviewhtml(Period)
# Out:
# <div id="injblock1004">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc1" style="background-color:LightGreen">item 0</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Sheet1</caption>
# ...

# %%
Dimensions = [
            HDim(Period,'Period',DIRECTLY,LEFT),
            HDim(Area,'Area', DIRECTLY, ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People (thousands)')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
savepreviewhtml(c1)
# Out:
# <div id="injblock1005">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0" style="background-color:Aqua">OBS</td><td class="xc1" style="background-color:LightGreen">Period</td><td class="xc2" style="background-color:MistyRose">Area</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Sheet1</caption>
# ...

# %%
new_table = c1.topandas()
new_table
# Out:
#            OBS            Period                          Area Measure Type  \
# 0      69701.0  Jan-02 to Mar-02                         TOTAL        Count
# 1      18150.0  Jan-02 to Mar-02           European Union EU15        Count
# 2       2217.0  Jan-02 to Mar-02            European Union EU8        Count
# 3       1269.0  Jan-02 to Mar-02            European Union EU2        Count
# 4        455.0  Jan-02 to Mar-02          European Union Other        Count
# 5       3114.0  Jan-02 to Mar-02                  Other Europe        Count
# 6       4411.0  Jan-02 to Mar-02  Middle East and Central Asia        Count
# 7       2390.0  Jan-02 to Mar-02                     East Asia        Count
# 8      10591.0  Jan-02 to Mar-02                    South Asia        Count
# 9       4063.0  Jan-02 to Mar-02               South East Asia        Count
# 10     11376.0  Jan-02 to Mar-02            Sub-Saharan Africa        Count
# ...

# %%
new_table.count()
# Out:
# OBS             1040
# Period          1040
# Area            1040
# Measure Type    1040
# Unit            1040
# dtype: int64

# %%
new_table.dtypes
# Out:
# OBS             float64
# Period           object
# Area             object
# Measure Type     object
# Unit             object
# dtype: object

# %%
new_table['Value'] = new_table['OBS'].astype(int)

# %%
new_table = new_table[['Period','Area','Measure Type','Value','Unit']]

# %%
new_table.head()
# Out:
#              Period                  Area Measure Type  Value  \
# 0  Jan-02 to Mar-02                 TOTAL        Count  69701
# 1  Jan-02 to Mar-02   European Union EU15        Count  18150
# 2  Jan-02 to Mar-02    European Union EU8        Count   2217
# 3  Jan-02 to Mar-02    European Union EU2        Count   1269
# 4  Jan-02 to Mar-02  European Union Other        Count    455
#
#                  Unit
# 0  People (thousands)
# 1  People (thousands)
# 2  People (thousands)
# 3  People (thousands)
# 4  People (thousands)

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('nin1.csv'), index = False)

# %%
# writeMetadata(metadata, 'Local Area Migration Indicators', 'Migration')

# %%
new_table.count()
# Out:
# Period          1040
# Area            1040
# Measure Type    1040
# Value           1040
# Unit            1040
# dtype: int64
